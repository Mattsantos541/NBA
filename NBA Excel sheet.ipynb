# %%
import pandas as pd

# %%
nba= pd.read_excel('tscorers#@.xls')

# %%
nba.drop()
# Out:
#     Unnamed: 0          Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0           Rk              Player       From         To         Tm
# 1            1      Michael Jordan       1985       2003        TOT
# 2            2        LeBron James       2004       2019        TOT
# 3            3        Kevin Durant       2008       2019        TOT
# 4            4       Allen Iverson       1997       2010        TOT
# 5            5       George Gervin       1980       1986        TOT
# 6            6      Adrian Dantley       1980       1991        TOT
# 7            7         Kobe Bryant       1997       2016        LAL
# 8            8         Karl Malone       1986       2004        TOT
# 9            9   Dominique Wilkins       1983       1999        TOT
# 10          10          Larry Bird       1980       1992        BOS
# 11          11         Joel Embiid       2017       2019        PHI
# 12          12        James Harden       2010       2019        TOT
# ...
